# %% [markdown]
# # Implement a stack using an array

# %%
class Stack:
    def __init__(self):
        self.arr = []
        self.size = 0
    
    def push(self, val):
        self.arr.append(val)
        self.size += 1
    
    def pop(self):
        if not self.isEmpty() :
            item = self.arr.pop(-1)
            self.size -= 1
            return item
        return None
    
    def isEmpty(self):
        if self.len() == 0 :
            return True
        return False
    
    def len(self):
        return self.size

# %%
stack = Stack()

# %%
stack.push("Hi")

# %%
print(stack.arr)
# Out:
# ['Hi']

# %%
stack.push('Whats up')

# %%
item = stack.pop()

# %%
item

# %%
stack

# %%
stack.arr
# Out:
# []

# %%
stack

# %%
class Stack:
    def __init__(self, initial_size=10):
        self.arr = [0 for _ in range(initial_size)]
        self.num_of_items = 0
        self.next_index = 0
    
    def push(self, value):
        if self.next_index == len(self.arr):
            print("max capcity reached. Increasing space..")
            self.handle_capacity()
        self.arr[self.next_index] = value
        self.next_index += 1
        self.num_of_items += 1
        return 
    
    def handle_capcity(self):
        old_arr = self.arr
        self.arr = [0 for _ in range(2*len(old_arr))]
        for index, value in enumerate(old_arr):
            self.arr[index] = value
            
    def pop(self):
        if not self.is_empty():
            item = self.arr.pop(self.next_index-1)
            self.next_index -= 1
            self.num_of_items -= 1
            return item
        return None
    
    def size(self):
        return self.num_of_items
    
    def is_empty(self):
        return self.num_of_items == 0

# %%
foo = Stack()
print(foo.size()) # Should return 0
print(foo.is_empty()) # Should return True
foo.push("Test") # Let's push an item onto the stack and check again
print(foo.size()) # Should return 1
print(foo.is_empty()) # Should return False
# Out:
# 0
# True
# 1
# False

# %%
foo = Stack()
foo.push("Test") # We first have to push an item so that we'll have something to pop
print(foo.pop()) # Should return the popped item, which is "Test"
print(foo.pop())
# Out:
# Test
# None

# %%
foo.size()
# Out:
# 0
