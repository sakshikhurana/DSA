# %% [markdown]
# # Flattening a nested linked list
# Suppose you have a linked list where the value of each node is a sorted linked list (i.e., it is a nested list). Your task is to flatten this nested list—that is, to combine all nested lists into a single (sorted) linked list.

# %%
# Use this class as the nodes in your linked list
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None

#     def __repr__(self):
#         return str(self.value)


class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, value):
        if self.head is None:
            self.head = Node(value)
            return
        node = self.head
        while node.next is not None:
            node = node.next
        node.next = Node(value)

# %%
def merge(list1, list2):
    merged = LinkedList()
    if list1 is None:
        return list2
    if list2 is None:
        return list1
    list1_elt = list1.head
    list2_elt = list2.head
    while list1_elt is not None or list2_elt is not None:
        if list1_elt is None:
            merged.append(list2_elt.value)
            list2_elt = list2_elt.next
        elif list2_elt is None:
            merged.append(list1_elt.value)
            list1_elt = list1_elt.next
        elif list1_elt.value <= list2_elt.value:
            merged.append(list1_elt.value)
            list1_elt = list1_elt.next
        else:
            merged.append(list2_elt.value)
            list2_elt = list2_elt.next
    return merged

class NestedLinkedList(LinkedList):
    def flatten(self):
        import pdb
        pdb.set_trace()
        return self._flatten(self.head)

    def _flatten(self, node):
        import pdb
        pdb.set_trace()
        if node.next is None:
            return merge(node.value, None)
        return merge(node.value, self._flatten(node.next))

# %%
linked_list = LinkedList()
linked_list.append(1)
linked_list.append(3)
linked_list.append(5)

second_linked_list = LinkedList()
second_linked_list.append(2)
second_linked_list.append(4)

merged = merge(linked_list, second_linked_list)

node = merged.head
while node is not None:
    #This will print 1 2 3 4 5
    print(node.value)
    node = node.next
    
# Lets make sure it works with a None list
merged = merge(None, linked_list)
node = merged.head
while node is not None:
    #This will print 1 2 3 4 5
    print(node.value)
    node = node.next
# Out:
# 1
# 2
# 3
# 4
# 5
# 1
# 3
# 5

# %%
import pdb
pdb.set_trace()
nested_linked_list = NestedLinkedList()
nested_linked_list.append(Node(linked_list))
nested_linked_list.append(second_linked_list)
flattened = nested_linked_list.flatten()

node = flattened.head
while node is not None:
    #This will print 1 2 3 4 5
    print(node.value)
    node = node.next
# Out:
# --Return--
# None
# > <ipython-input-4-d54e9208385d>(2)<module>()
#       1 import pdb
# ----> 2 pdb.set_trace()
#       3 nested_linked_list = NestedLinkedList()
#       4 nested_linked_list.append(Node(linked_list))
#       5 nested_linked_list.append(second_linked_list)
#
# ipdb> n
#     [... skipped 1 hidden frame]
#
#     [... skipped 1 hidden frame]
#
#     [... skipped 1 hidden frame]
#
#     [... skipped 1 hidden frame]
#
# > /Users/sakshikhurana/Library/Python/3.7/lib/python/site-packages/IPython/core/interactiveshell.py(3339)run_ast_nodes()
#    3337                     to_run.append((node, 'single'))
#    3338
# -> 3339                 for node,mode in to_run:
#    3340                     if mode == 'exec':
#    3341                         mod = Module([node], [])
#
# ipdb> c
# > <ipython-input-2-408e5ba3cb7e>(28)flatten()
#      26         import pdb
#      27         pdb.set_trace()
# ---> 28         return self._flatten(self.head)
#      29
#      30     def _flatten(self, node):
#
# ipdb> self.head
# <__main__.Node object at 0x10a5c8d50>
# ipdb> self.head.value
# <__main__.Node object at 0x10a5e0650>
# ipdb> self.head.next.value
# <__main__.LinkedList object at 0x10a5c8950>
# ipdb> c
# > <ipython-input-2-408e5ba3cb7e>(33)_flatten()
#      31         import pdb
#      32         pdb.set_trace()
# ---> 33         if node.next is None:
#      34             return merge(node.value, None)
#      35         return merge(node.value, self._flatten(node.next))
#
# ipdb> c
# > <ipython-input-2-408e5ba3cb7e>(33)_flatten()
#      31         import pdb
#      32         pdb.set_trace()
# ---> 33         if node.next is None:
#      34             return merge(node.value, None)
#      35         return merge(node.value, self._flatten(node.next))
#
# ipdb> c
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-d54e9208385d> in <module>
#       4 nested_linked_list.append(Node(linked_list))
#       5 nested_linked_list.append(second_linked_list)
# ----> 6 flattened = nested_linked_list.flatten()
#       7
#       8 node = flattened.head
#
# <ipython-input-2-408e5ba3cb7e> in flatten(self)
#      26         import pdb
#      27         pdb.set_trace()
# ---> 28         return self._flatten(self.head)
#      29
#      30     def _flatten(self, node):
#
# <ipython-input-2-408e5ba3cb7e> in _flatten(self, node)
#      33         if node.next is None:
#      34             return merge(node.value, None)
# ---> 35         return merge(node.value, self._flatten(node.next))
#
# <ipython-input-2-408e5ba3cb7e> in merge(list1, list2)
#       5     if list2 is None:
#       6         return list1
# ----> 7     list1_elt = list1.head
#       8     list2_elt = list2.head
#       9     while list1_elt is not None or list2_elt is not None:
#
# AttributeError: 'Node' object has no attribute 'head'
